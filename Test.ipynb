# %%
pip install gmaps

# notwendige Imports -> pip install gmaps (muss gemacht sein)
import requests
import gmaps

# indivdueller Google Maps API Schlüssel (verschlüsseln?)
API_KEY = ""

# http request für geocode API, verwandelt Adressen und Stadtnamen in Koordinaten
# Quelle: https://www.youtube.com/watch?v=yOXQAmYl0Aw&t=105s
def get_coordinates(place):
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={place}&key={API_KEY}"
    response = requests.get(url)
    #überprüfen ob code == 200 (Verbindung OK)
    if response.status_code == 200:
        data = response.json()
        if "results" in data and len(data["results"]) > 0:
            location = data["results"][0]["geometry"]["location"]
            return location["lat"], location["lng"]
    return None, None

# Eingabe der Start sowie Zieldestinationen (Unendlich viele Startdestinationen möglich)
origins = input("Geben Sie Startpunkte durch Komma getrennt ein (z.B. Genf, Zürich HB, Dufourstrasse 50 9000): ").split(",")
destination = input("Geben Sie Ihre Zieldestination ein: ")

# Überprüfung, dass mindestens ein Startpunkt angegeben wurde ansonsten aufforderung eine anzugeben 
if len(origins) < 1:
    print("Bitte geben Sie mindestens einen Startpunkt ein.")
    exit()

# Liste von Farben für die Routen in RGB Code -> Nötig, damit Gmaps diese lesen kann
# Quelle: https://htmlcolorcodes.com/
colors = [(0, 0, 255), (255, 0, 0), (0, 255, 0), (255, 255, 0), (255, 165, 0), (128, 0, 128), (255, 192, 203)]

# Konfiguration der Karte mit Höhe und Breite und Hinterlegung in fig
gmaps.configure(api_key=API_KEY)
fig = gmaps.figure(layout = {"width": "1550px", "height": "600px"})

# Durchlauf der verschiedenen Startpunkte mittels for Schleife
# Quelle: Angepasst aus ChatGPT
for i, origin in enumerate(origins):
    # Überprüfen ob der Standort eine Adresse ist 
    if ',' in origin:  # Bei der Adresse kann eine Postleitzahl hinzugefügt werden um Doppelungen zu vermeiden jedoch nicht zwingend notwendig 
        place, postal_code = origin.split(',', 1)
        start_latlng = get_coordinates(place.strip())  # Koordinaten werden abgerufen und geladen
        if start_latlng[0] is None or start_latlng[1] is None:
            #Falls Adresse falsch keine Koordinaten gefunden
            print(f"Ort nicht gefunden für {place}")
            continue
    # Falls keine Adresse direkt die Koordinaten des Ortenamens auslesen
    else:
        start_latlng = get_coordinates(origin.strip())  # Koordinaten des Startpunkts abrufen
        if start_latlng[0] is None or start_latlng[1] is None:
            # Falls Ort falsch keine Koordinaten gefunden
            print(f"Ort nicht gefunden für {origin}")
            continue

    # http Anfrage für Routes API zur Bestimmung der Route
    # Quelle: https://www.youtube.com/watch?v=yOXQAmYl0Aw&t=105s
    url_origin = f"https://maps.googleapis.com/maps/api/directions/json?origin={start_latlng[0]},{start_latlng[1]}&destination={destination}&key={API_KEY}"

    # Sende http get Anfrage
    response_origin = requests.get(url_origin)

    # Überprüfe, ob die Anfrage erfolgreich war (Status Code 200 -> OK)
    if response_origin.status_code == 200:
        # Extrahiere Daten aus der Antwort (im JSON-Format)
        data_origin = response_origin.json()

        # Überprüfen ob eine Route zwischen den Koordinaten gefunden werden kann
        # Quelle: Angepasst aus ChatGPT
        if "routes" in data_origin and len(data_origin["routes"]) > 0:
            # Eintrag der Startkoordinaten
            start_location_origin = (data_origin["routes"][0]["legs"][0]["start_location"]["lat"], data_origin["routes"][0]["legs"][0]["start_location"]["lng"],)
            # Eintrag der Endkoordinaten
            end_location_origin = (data_origin["routes"][0]["legs"][0]["end_location"]["lat"], data_origin["routes"][0]["legs"][0]["end_location"]["lng"],)

            # Farbe der Route festlegen
            # Quelle: https://stackoverflow.com/questions/18729180/understanding-the-modulus-operator
            color = colors[i % len(colors)]

            # Angaben welche Art der Route hier Transit -> ÖV, sowie die Darstellung der Route (Farbe, Breite sowie Deckkraft)
            # Quelle: https://developers.google.com/maps/documentation/routes
            # Quelle: https://www.youtube.com/watch?v=mXGyH8_FcMQ&t=5s
            transit_layer_origin = gmaps.directions_layer(
                start = start_location_origin,
                end = end_location_origin,
                travel_mode = "TRANSIT",
                stroke_color = color,
                stroke_weight = 3.0,
                stroke_opacity = 1.0,)
            
            # Layer der Route auf die Karte hinzufügen
            fig.add_layer(transit_layer_origin)
            
        else:
            print(f"Keine Route gefunden für Startpunkt {origin}")
    else:
        print(f"Fehler in Anfrage für Startpunkt {origin}: {response_origin.status_code}")

# Erstellung der Karte
fig

# %%
pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\ramha\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\ramha\anaconda3\lib\site-packages (from gmaps) (8.20.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\ramha\anaconda3\lib\site-packages (from gmaps) (5.7.1)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from gmaps) (3.1.0)
# Requirement already satisfied: six in c:\users\ramha\anaconda3\lib\site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: decorator in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: colorama in c:\users\ramha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ramha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ramha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ramha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ramha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.0.9)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.5.0)
# Requirement already satisfied: nest-asyncio in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.6.0)
# Requirement already satisfied: packaging in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (23.1)
# Requirement already satisfied: psutil in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\ramha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ramha\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: fastjsonschema in c:\users\ramha\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ramha\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.19.2)
# Requirement already satisfied: wcwidth in c:\users\ramha\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ramha\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (7.0.8)
# Requirement already satisfied: executing in c:\users\ramha\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ramha\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ramha\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ramha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\ramha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\ramha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ramha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (7.10.0)
# Requirement already satisfied: overrides in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ramha\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ramha\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.6)
# Requirement already satisfied: requests>=2.31 in c:\users\ramha\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ramha\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ramha\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\ramha\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramha\anaconda3\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.1.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ramha\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\ramha\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ramha\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramha\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramha\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ramha\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\ramha\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.1)
# Requirement already satisfied: uri-template in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\ramha\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ramha\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ramha\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.5)
# Requirement already satisfied: pycparser in c:\users\ramha\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ramha\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
